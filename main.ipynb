# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = []
with open("data.csv", "r") as f:
    for line in f:
        data.append(line.split(","))

data = np.array(data)

# %%
plt.plot(data.T[1])
